# %%
import pandas as pd
import numpy as np
import requests
import time

# %%
https://eodhistoricaldata.com/api/news?api_token=OeAFFmMliFG5orCUuwAKQ8l4WWFQ67YX&t=AAPL.US&offset=0&limit=10

# %%
base_url= 'https://eodhistoricaldata.com/api/news?api_token=614399b04bd166.13603221'
tag = '&t=research analysis and reports'

# %%
res = requests.get(base_url + tag)

# %%
res.text
# Out:
# '[{"date":"2021-09-24T09:28:00+00:00","title":"Singapore Data Center Colocation Services Markets 2021 - Adoption of Disruptive Technologies and 5G Implementation Will Boost Data Center Retail Colocation Demand","content":"Dublin, Sept.  24, 2021  (GLOBE NEWSWIRE) -- The \\"Singapore Data Center Colocation Services Growth Opportunities\\" report has been added to ResearchAndMarkets.com\'s offering.\\n\\nSingapore is a leading data center colocation services market in the Asia-Pacific region.\\n\\nWith increasing digital transformation, favorable government policies, and a business-friendly market, the market is expected to maintain robust growth. Enterprises are shifting their focus toward disruptive technologies and 5G implementations to boost colocation demand, ultimately stimulating the need for hyperscale colocation services.\\n\\nSingapore\'s strong connectivity infrastructure and high internet penetration enhance its attractiveness as a data center hub in Asia-Pacific. The globa
# ...

# %%
res
# Out:
# <Response [200]>

# %%
type(res.json())
# Out:
# list

# %%
trial = res.json()

# %%
trial
# Out:
# [{'date': '2021-09-24T09:28:00+00:00',
#   'title': 'Singapore Data Center Colocation Services Markets 2021 - Adoption of Disruptive Technologies and 5G Implementation Will Boost Data Center Retail Colocation Demand',
# ...
